# %% [markdown]
# ## Multiple Logging

# %%
import logging

# %%
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

# %%
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
logger1.debug("This is a debug message for logger 1")
logger2.warning("This is a warning message for logger 2")
# Out:
# 2025-11-28 00:27:13 - module1 - DEBUG - This is a debug message for logger 1
# 2025-11-28 00:27:13 - module2 - WARNING - This is a warning message for logger 2
